# %%
# !pip install statsmodels matplotlib

# %%
import sys, os
import numpy as np
import pandas as pd
import statsmodels.stats.api as sms

sys.path.append("..")

ROOT_PATH = '/workspace/deeppose/training/logs/'
LOGS_PATH = os.path.join(ROOT_PATH, 'deeppose_paper2021_miniunity')

# %%
from glob import glob
import pandas as pd
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator

metrics = ['benchmark/test/random/fk', 'benchmark/test/random/position', 'benchmark/test/random/rotation',
           'benchmark/test/fivepoint/fk', 'benchmark/test/fivepoint/position', 'benchmark/test/fivepoint/rotation'
          ]


def read_experiment_data(experiement_dir, experiment_pattern, metrics=None):
    experiemnt_folder_list = glob(os.path.join(experiement_dir, experiment_pattern))
    experiment_data_tst = {}
    index_max_tst = 0
    
    i=0    
    for experiement in experiemnt_folder_list:
        print(experiement)
#         print(glob(os.path.join(experiement, 'events.out.tfevents.*')))
        df_tst=[]
        df_val=[]
        for file in glob(os.path.join(experiement, 'events.out.tfevents.*')):
            ea = EventAccumulator(file)
            ea.Reload()
            tags = ea.Tags()['scalars']
            # print(tags)
            
            if not metrics[0] in tags:
                continue 
                
            columns = []
            for m in metrics:
                df = pd.DataFrame(ea.Scalars(m)).set_index('step').drop('wall_time', axis=1)
                df.columns = [m]
                columns.append(df)
            data = pd.concat(columns, axis=1)
            if len(data) > 0:
                df_tst.append(data)
         
        if len(df_tst) > 0:
            df_tst = pd.concat(df_tst).sort_index()
        
        if len(df_tst) > 0:
            experiment_data_tst[experiement+file] = df_tst
    
    return experiment_data_tst


def get_stats(df: pd.DataFrame, stats_steps = 100):

    df_observations = []
    for k, v in df.items():
        df_observations.append(v[-stats_steps:])

    df_observations = pd.concat(df_observations)
    df_stats = pd.DataFrame(df_observations.mean(), columns=['mean'])
    df_stats['ci_low'] = sms.DescrStatsW(df_observations).tconfint_mean()[0]
    df_stats['ci_high'] = sms.DescrStatsW(df_observations).tconfint_mean()[1]
    
    return df_stats

# %%
# r720-2
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_3-num_blocks_ikd_3-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_3-num_blocks_ikd_3-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_3-num_blocks_ikd_3-fk_loss_scale_100.0
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00328  0.00327  0.00329
# benchmark/test/random/position     0.00094  0.00093  0.00094
# benchmark/test/random/rotation     0.18173  0.18156  0.18189
# benchmark/test/fivepoint/fk        0.00174  0.00173  0.00175
# benchmark/test/fivepoint/position  0.00076  0.00075  0.00077
# benchmark/test/fivepoint/rotation  0.20369  0.20342  0.20396

# %%
# r720-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_3-num_blocks_ikd_0-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_3-num_blocks_ikd_0-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_3-num_blocks_ikd_0-fk_loss_scale_100.0
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00365  0.00363  0.00366
# benchmark/test/random/position     0.00105  0.00104  0.00106
# benchmark/test/random/rotation     0.19394  0.19376  0.19412
# benchmark/test/fivepoint/fk        0.00184  0.00183  0.00185
# benchmark/test/fivepoint/position  0.00082  0.00082  0.00083
# benchmark/test/fivepoint/rotation  0.21181  0.21149  0.21213

# %%
# r720-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_3-num_blocks_ikd_1-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_3-num_blocks_ikd_1-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_3-num_blocks_ikd_1-fk_loss_scale_100.0
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00352  0.00351  0.00353
# benchmark/test/random/position     0.00093  0.00092  0.00093
# benchmark/test/random/rotation     0.18953  0.18937  0.18969
# benchmark/test/fivepoint/fk        0.00187  0.00186  0.00188
# benchmark/test/fivepoint/position  0.00080  0.00079  0.00080
# benchmark/test/fivepoint/rotation  0.20925  0.20901  0.20949

# %%
# r720-2
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_3-num_blocks_ikd_2-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_3-num_blocks_ikd_2-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_3-num_blocks_ikd_2-fk_loss_scale_100.0
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00334  0.00333  0.00335
# benchmark/test/random/position  0.00093  0.00092  0.00093
# benchmark/test/random/rotation  0.18400  0.18384  0.18416

# %%
# lambda-dual2
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_5-num_blocks_ikd_0-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_5-num_blocks_ikd_0-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_5-num_blocks_ikd_0-fk_loss_scale_100.0
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00327  0.00326  0.00328
# benchmark/test/random/position  0.00084  0.00084  0.00085
# benchmark/test/random/rotation  0.18242  0.18223  0.18261

# %%
# lambda-dual2
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_5-num_blocks_ikd_1-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_5-num_blocks_ikd_1-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_5-num_blocks_ikd_1-fk_loss_scale_100.0
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00324  0.00323  0.00325
# benchmark/test/random/position  0.00081  0.00081  0.00082
# benchmark/test/random/rotation  0.18184  0.18164  0.18204

# %%
# lambda-dual2
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_5-num_blocks_ikd_2-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_5-num_blocks_ikd_2-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_5-num_blocks_ikd_2-fk_loss_scale_100.0
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00310  0.00309  0.00311
# benchmark/test/random/position     0.00077  0.00076  0.00078
# benchmark/test/random/rotation     0.17911  0.17893  0.17930
# benchmark/test/fivepoint/fk        0.00164  0.00163  0.00165
# benchmark/test/fivepoint/position  0.00069  0.00068  0.00070
# benchmark/test/fivepoint/rotation  0.19987  0.19955  0.20019

# %%
# lambda-a6000-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_5-num_blocks_ikd_3-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_5-num_blocks_ikd_3-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_5-num_blocks_ikd_3-fk_loss_scale_100.0
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00307  0.00306  0.00309
# benchmark/test/random/position  0.00082  0.00081  0.00083
# benchmark/test/random/rotation  0.17847  0.17822  0.17871

# %%
# lambda-a6000-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_7-num_blocks_ikd_0-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_7-num_blocks_ikd_0-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_7-num_blocks_ikd_0-fk_loss_scale_100.0
#                                        mean    ci_low   ci_high
# benchmark/test/random/fk           0.002985  0.002972  0.002997
# benchmark/test/random/position     0.000745  0.000737  0.000752
# benchmark/test/random/rotation     0.176204  0.175996  0.176411
# benchmark/test/fivepoint/fk        0.001645  0.001636  0.001653
# benchmark/test/fivepoint/position  0.000672  0.000666  0.000679
# benchmark/test/fivepoint/rotation  0.199111  0.198826  0.199397

# %%
# lambda-a6000-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_7-num_blocks_ikd_1-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_7-num_blocks_ikd_1-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_7-num_blocks_ikd_1-fk_loss_scale_100.0
#                                        mean    ci_low   ci_high
# benchmark/test/random/fk           0.003072  0.003059  0.003084
# benchmark/test/random/position     0.000788  0.000782  0.000794
# benchmark/test/random/rotation     0.177955  0.177683  0.178227
# benchmark/test/fivepoint/fk        0.001637  0.001629  0.001644
# benchmark/test/fivepoint/position  0.000701  0.000694  0.000707
# benchmark/test/fivepoint/rotation  0.199277  0.198935  0.199619

# %%
# lambda-a6000-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_7-num_blocks_ikd_2-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_7-num_blocks_ikd_2-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_7-num_blocks_ikd_2-fk_loss_scale_100.0
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00310  0.00309  0.00312
# benchmark/test/random/position     0.00078  0.00077  0.00079
# benchmark/test/random/rotation     0.17798  0.17771  0.17825
# benchmark/test/fivepoint/fk        0.00163  0.00161  0.00164
# benchmark/test/fivepoint/position  0.00067  0.00065  0.00068
# benchmark/test/fivepoint/rotation  0.19823  0.19774  0.19872

# %%
# lambda-a6000-1
experiment = 'encoder_blocks/seed_*-num_blocks_encoder_7-num_blocks_ikd_3-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_0-num_blocks_encoder_7-num_blocks_ikd_3-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/encoder_blocks/seed_1-num_blocks_encoder_7-num_blocks_ikd_3-fk_loss_scale_100.0
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00314  0.00312  0.00315
# benchmark/test/random/position  0.00082  0.00081  0.00083
# benchmark/test/random/rotation  0.17827  0.17801  0.17853

# %% [markdown]
# ## PointResNEt

# %%
# lambda-dual2
experiment = 'rebuttal/point_resnet/seed_*-num_blocks_enc_3'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_1-num_blocks_enc_3
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_0-num_blocks_enc_3
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_2-num_blocks_enc_3
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_3-num_blocks_enc_3
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00323  0.00322  0.00325
# benchmark/test/random/position  0.00092  0.00091  0.00092
# benchmark/test/random/rotation  0.18175  0.18156  0.18194

# %%
# lambda-dual2
experiment = 'rebuttal/point_resnet/seed_*-num_blocks_enc_5'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_3-num_blocks_enc_5
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_1-num_blocks_enc_5
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_0-num_blocks_enc_5
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_2-num_blocks_enc_5
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00322  0.00321  0.00323
# benchmark/test/random/position  0.00088  0.00087  0.00088
# benchmark/test/random/rotation  0.18085  0.18067  0.18102

# %%
# lambda-dual2
experiment = 'rebuttal/point_resnet/seed_*-num_blocks_enc_7'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_3-num_blocks_enc_7
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_1-num_blocks_enc_7
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_0-num_blocks_enc_7
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/rebuttal/point_resnet/seed_2-num_blocks_enc_7
#                                    mean   ci_low  ci_high
# benchmark/test/random/fk        0.00349  0.00346  0.00352
# benchmark/test/random/position  0.00099  0.00097  0.00101
# benchmark/test/random/rotation  0.18640  0.18580  0.18700

# %% [markdown]
# ## Transformer

# %%
# lambda-dual2
experiment = 'transformer/Transformer-seed-*-dmodel_128-dimfeedforward_1024-nhead_8-transformer_layers_2-fk_loss_scale_100.0-fcr_blocks_6'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/transformer/Transformer-seed-1-dmodel_128-dimfeedforward_1024-nhead_8-transformer_layers_2-fk_loss_scale_100.0-fcr_blocks_6
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/transformer/Transformer-seed-0-dmodel_128-dimfeedforward_1024-nhead_8-transformer_layers_2-fk_loss_scale_100.0-fcr_blocks_6
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00349  0.00347  0.00350
# benchmark/test/random/position     0.00127  0.00126  0.00128
# benchmark/test/random/rotation     0.20043  0.20025  0.20061
# benchmark/test/fivepoint/fk        0.00179  0.00178  0.00180
# benchmark/test/fivepoint/position  0.00092  0.00090  0.00093
# benchmark/test/fivepoint/rotation  0.21379  0.21352  0.21407

# %% [markdown]
# ## Ablation GPD

# %%
# R720-1

experiment = 'ablation_gpd/SingleStage-seed_*-num_blocks_stage_6-fk_loss_scale_100.0'

df = read_experiment_data(experiement_dir=os.path.join(ROOT_PATH, LOGS_PATH), experiment_pattern=experiment, metrics=metrics)
get_stats(df).round(5)
# Out:
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/ablation_gpd/SingleStage-seed_0-num_blocks_stage_6-fk_loss_scale_100.0
# /workspace/deeppose/training/logs/deeppose_paper2021_miniunity/ablation_gpd/SingleStage-seed_1-num_blocks_stage_6-fk_loss_scale_100.0
#                                       mean   ci_low  ci_high
# benchmark/test/random/fk           0.00334  0.00332  0.00335
# benchmark/test/random/position     0.00092  0.00091  0.00093
# benchmark/test/random/rotation     0.18300  0.18277  0.18323
# benchmark/test/fivepoint/fk        0.00183  0.00182  0.00185
# benchmark/test/fivepoint/position  0.00080  0.00079  0.00081
# benchmark/test/fivepoint/rotation  0.20395  0.20357  0.20434
